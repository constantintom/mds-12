# %% [markdown]
# # Домашнее задание "Теория вероятности. Непрерывные Случайные Величины".

# %% [markdown]
# ## Уровень 0:

# %% [markdown]
# - Задание 1:

# %% [markdown]
# Получить интуицию, на что влияют параметры распределений. Построить по 5 функций плотностей с разными параметрами для каждого распределения: нормальное, экспоненциальное, Стьюдента на одном графике.

# %%
import numpy as np
import scipy.stats as sts
from scipy.stats import norm
import matplotlib.pyplot as plt

# %%
mu_arr = np.linspace(1.0, 6.0, 5)
var_arr = np.linspace(0.1, 0.6, 5)
x = np.linspace(0, 8, 100)
def f(x, norm):    
    pdf = norm.pdf(x)
    return pdf

# %%
fig, axes = plt.subplots(figsize = (15, 6))
plt.title('Плотность нормального распределения вероятности')
axes.set_xlabel('x', fontsize = 12)
axes.set_ylabel('$f(x)$', fontsize = 12)
for mu, var in zip(mu_arr, var_arr):
    norm = sts.norm(loc = mu, scale = var)
    axes.plot(x, f(x, norm), label = [mu, var])
    axes.legend(loc='best', frameon=False)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
lam_arr = np.linspace(0.1, 6.0, 5)
x = np.linspace(0, 10, 100)
def f(x, expon):    
    pdf = expon.pdf(x)
    return pdf

# %%
fig, axes = plt.subplots(figsize = (15, 6))
plt.title('Плотность экспоненциального распределения вероятности')
axes.set_xlabel('x', fontsize = 12)
axes.set_ylabel('$f(x)$', fontsize = 12)

for lam in lam_arr:
    expon = sts.expon(lam)
    axes.plot(x, f(x, expon), label = lam)
    axes.legend(loc='best', frameon=False)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
n_arr = np.linspace(1.0, 10.0, 5)
x = np.linspace(-8, 8, 100)
def f(x, t):    
    pdf = t.pdf(x)
    return pdf

# %%
fig, axes = plt.subplots(figsize = (15, 6))
plt.title('Плотность распределения вероятности по Стьюденту ')
axes.set_xlabel('x', fontsize = 12)
axes.set_ylabel('$f(x)$', fontsize = 12)
for n in n_arr:
    t = sts.t(n)
    axes.plot(x, f(x, t), label = n)
    axes.legend(loc='best', frameon=False)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Уровень 1:

# %% [markdown]
# - Задание 2

# %% [markdown]
# Непрерывная случайная величина задана плотностью распределения:$$ f(\xi) = C, \xi \in [0;5];f(\xi) = 0, \xi \notin [0;5]$$Найдите C, математическое ожидание $\xi$ а также вероятность попадания  в отрезок $[3.5;7]$, т.е. P(3.5 &lt; $\xi$ &lt; 7).

# %%
from scipy.stats import uniform
a = 0
b = 5
uniform = sts.uniform(a, b-a)
C =  uniform.pdf(3)
print('C:', C)
print('математическое ожидание:', uniform.mean())
print('вероятность попадания в отрезок [3.5;7]:', uniform.cdf(7) - uniform.cdf(3.5))
# Out:
# C: 0.2
# математическое ожидание: 2.5
# вероятность попадания в отрезок [3.5;7]: 0.30000000000000004

# %% [markdown]
# - Задание 3

# %% [markdown]
# Известно, что светофор горит 54 секунды красным, 4 секунды жёлтым и 28 секунд зелёным. Посчитайте, какое количество информации несёт сообщение о цвете светофора в текущий момент. А что будет в случае 28, 28 и 28 секунд для каждого цвета?

# %%
import math
n = 54 + 4 + 28
p1 = 54/n
p2 = 4/n
p3 = 28/n
I1 = -(p1* math.log2(p1) + p2* math.log2(p2) + p3* math.log2(p3))
I2 = math.log2(3)
print(f'Кол-во информации: I1-{I1:.2f}, I2-{I2:.2f}')
# Out:
# Кол-во информации: I1-1.15, I2-1.58
